# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('Advertising.csv')
data.drop(['Unnamed: 0'],axis=1,inplace=True)
sns.heatmap(data.corr(),annot=True)
features=data[['TV']].values
target=data[['sales']].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(features,target,random_state=40,train_size=0.75)
from sklearn.linear_model import LinearRegression
linear_regression=LinearRegression()
linear_regression.fit(x_train,y_train)
print(" coef value:-",linear_regression.coef_)
print("intercept value:-",linear_regression.intercept_) 
print(x_new)
predict=linear_regression.predict(x_new)
print("predicted_value :-",predict)
# Out:
#  coef value:- [[0.04846571]]
# intercept value:- [6.91716082]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 17>()
#      15 print(" coef value:-",linear_regression.coef_)
#      16 print("intercept value:-",linear_regression.intercept_)
# ---> 17 print(x_new)
#      18 predict=linear_regression.predict(x_new)
#      19 print("predicted_value :-",predict)
#
# NameError: name 'x_new' is not defined
